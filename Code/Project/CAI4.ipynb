# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import PPO2

# multiprocess environment
env = gym.make('CartPole-v1')

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo2_cartpole")

del model # remove to demonstrate saving and loading

model = PPO2.load("ppo2_cartpole")

# Enjoy trained agent
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13c11f810>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13c11f810>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13c11f810>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13c11f810>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13da86c10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13da86c10>>: AttributeError: module 'gast' has no attribute 'Num'
# /Users/mats/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13da86c10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13da86c10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# --------------------------------------
# | approxkl           | 3.6504375e-07 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0498       |
# | fps                | 372           |
# | n_updates          | 1             |
# | policy_entropy     | 0.69314355    |
# | policy_loss        | 5.6935824e-05 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 1.48e-05      |
# | total_timesteps    | 128           |
# | value_loss         | 36.87038      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.0139228e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0623       |
# | fps                | 2006          |
# | n_updates          | 2             |
# | policy_entropy     | 0.69304967    |
# | policy_loss        | -0.0028296316 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.345         |
# | total_timesteps    | 256           |
# | value_loss         | 49.332954     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0001224594   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0052         |
# | fps                | 1995           |
# | n_updates          | 3              |
# | policy_entropy     | 0.69221365     |
# | policy_loss        | -0.00086395873 |
# | serial_timesteps   | 384            |
# | time_elapsed       | 0.409          |
# | total_timesteps    | 384            |
# | value_loss         | 24.969742      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.866196e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0504        |
# | fps                | 1965          |
# | n_updates          | 4             |
# | policy_entropy     | 0.6914905     |
# | policy_loss        | -0.0039483747 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 0.474         |
# | total_timesteps    | 512           |
# | value_loss         | 68.87519      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.583794e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0178       |
# | fps                | 1930          |
# | n_updates          | 5             |
# | policy_entropy     | 0.6909361     |
# | policy_loss        | -0.0014427538 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 0.54          |
# | total_timesteps    | 640           |
# | value_loss         | 56.154953     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.485501e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00632       |
# | fps                | 1754          |
# | n_updates          | 6             |
# | policy_entropy     | 0.68780625    |
# | policy_loss        | -0.0012472894 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 0.607         |
# | total_timesteps    | 768           |
# | value_loss         | 56.919777     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.0739275e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0185        |
# | fps                | 1946           |
# | n_updates          | 7              |
# | policy_entropy     | 0.6879967      |
# | policy_loss        | -0.00024564902 |
# | serial_timesteps   | 896            |
# | time_elapsed       | 0.681          |
# | total_timesteps    | 896            |
# | value_loss         | 59.282078      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.000102032034 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00669        |
# | fps                | 1836           |
# | n_updates          | 8              |
# | policy_entropy     | 0.6806533      |
# | policy_loss        | -0.0020441534  |
# | serial_timesteps   | 1024           |
# | time_elapsed       | 0.747          |
# | total_timesteps    | 1024           |
# | value_loss         | 25.905365      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0004639906  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00641       |
# | fps                | 2012          |
# | n_updates          | 9             |
# | policy_entropy     | 0.6779068     |
# | policy_loss        | -0.0060112593 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 0.818         |
# | total_timesteps    | 1152          |
# | value_loss         | 26.583538     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010411071 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.000702    |
# | fps                | 1698         |
# | n_updates          | 10           |
# | policy_entropy     | 0.66149265   |
# | policy_loss        | -0.008059021 |
# | serial_timesteps   | 1280         |
# | time_elapsed       | 0.882        |
# | total_timesteps    | 1280         |
# | value_loss         | 31.108675    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0007278466 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.00781      |
# | fps                | 1969         |
# | n_updates          | 11           |
# | policy_entropy     | 0.6488581    |
# | policy_loss        | -0.003499569 |
# | serial_timesteps   | 1408         |
# | time_elapsed       | 0.958        |
# | total_timesteps    | 1408         |
# | value_loss         | 33.92582     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00027220472 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0648       |
# | fps                | 1935          |
# | n_updates          | 12            |
# | policy_entropy     | 0.6547961     |
# | policy_loss        | -0.0008457899 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 1.02          |
# | total_timesteps    | 1536          |
# | value_loss         | 50.467392     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.6917e-05    |
# | clipfrac           | 0.0           |
# | explained_variance | 0.017         |
# | fps                | 2099          |
# | n_updates          | 13            |
# | policy_entropy     | 0.6389427     |
# | policy_loss        | -0.0026183538 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 1.09          |
# | total_timesteps    | 1664          |
# | value_loss         | 52.01207      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006494011  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00787       |
# | fps                | 2103          |
# | n_updates          | 14            |
# | policy_entropy     | 0.6282093     |
# | policy_loss        | -0.0067828572 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 1.15          |
# | total_timesteps    | 1792          |
# | value_loss         | 49.70808      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009908365 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -0.0156      |
# | fps                | 1993         |
# | n_updates          | 15           |
# | policy_entropy     | 0.6090524    |
# | policy_loss        | -0.008459561 |
# | serial_timesteps   | 1920         |
# | time_elapsed       | 1.21         |
# | total_timesteps    | 1920         |
# | value_loss         | 41.13167     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00038173035 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00656       |
# | fps                | 2013          |
# | n_updates          | 16            |
# | policy_entropy     | 0.6192586     |
# | policy_loss        | -0.0030504246 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 1.28          |
# | total_timesteps    | 2048          |
# | value_loss         | 49.46665      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002584278  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0416        |
# | fps                | 2029          |
# | n_updates          | 17            |
# | policy_entropy     | 0.6110567     |
# | policy_loss        | -0.0031473623 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 1.34          |
# | total_timesteps    | 2176          |
# | value_loss         | 67.524025     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025340816 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.062         |
# | fps                | 2018          |
# | n_updates          | 18            |
# | policy_entropy     | 0.6122921     |
# | policy_loss        | -0.0030828677 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 1.41          |
# | total_timesteps    | 2304          |
# | value_loss         | 83.94861      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.6660076e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.105         |
# | fps                | 2017           |
# | n_updates          | 19             |
# | policy_entropy     | 0.61763144     |
# | policy_loss        | -0.00022148143 |
# | serial_timesteps   | 2432           |
# | time_elapsed       | 1.47           |
# | total_timesteps    | 2432           |
# | value_loss         | 61.11566       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.4039698e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0915       |
# | fps                | 2012          |
# | n_updates          | 20            |
# | policy_entropy     | 0.6265657     |
# | policy_loss        | 0.000350366   |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 1.53          |
# | total_timesteps    | 2560          |
# | value_loss         | 69.04529      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.7211802e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0538        |
# | fps                | 2102           |
# | n_updates          | 21             |
# | policy_entropy     | 0.6064871      |
# | policy_loss        | -0.00037599425 |
# | serial_timesteps   | 2688           |
# | time_elapsed       | 1.6            |
# | total_timesteps    | 2688           |
# | value_loss         | 93.50169       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.9320734e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0126        |
# | fps                | 2135          |
# | n_updates          | 22            |
# | policy_entropy     | 0.61450666    |
# | policy_loss        | -0.0007056287 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 1.66          |
# | total_timesteps    | 2816          |
# | value_loss         | 62.7063       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021323792 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0223        |
# | fps                | 2135          |
# | n_updates          | 23            |
# | policy_entropy     | 0.590901      |
# | policy_loss        | -0.003564132  |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 1.72          |
# | total_timesteps    | 2944          |
# | value_loss         | 65.42737      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023850193 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0882       |
# | fps                | 2231          |
# | n_updates          | 24            |
# | policy_entropy     | 0.6052392     |
# | policy_loss        | 0.00073897745 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 1.78          |
# | total_timesteps    | 3072          |
# | value_loss         | 76.66715      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.3501214e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.033         |
# | fps                | 2202           |
# | n_updates          | 25             |
# | policy_entropy     | 0.59618247     |
# | policy_loss        | -0.00030531897 |
# | serial_timesteps   | 3200           |
# | time_elapsed       | 1.84           |
# | total_timesteps    | 3200           |
# | value_loss         | 56.12551       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00019475637  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0367         |
# | fps                | 2212           |
# | n_updates          | 26             |
# | policy_entropy     | 0.6251365      |
# | policy_loss        | -0.00081855257 |
# | serial_timesteps   | 3328           |
# | time_elapsed       | 1.9            |
# | total_timesteps    | 3328           |
# | value_loss         | 87.1082        |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 8.951785e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.156          |
# | fps                | 2127           |
# | n_updates          | 27             |
# | policy_entropy     | 0.6290824      |
# | policy_loss        | -0.00086824864 |
# | serial_timesteps   | 3456           |
# | time_elapsed       | 1.96           |
# | total_timesteps    | 3456           |
# | value_loss         | 62.647533      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.9381643e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0731        |
# | fps                | 2062          |
# | n_updates          | 28            |
# | policy_entropy     | 0.6023921     |
# | policy_loss        | 0.00012448977 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 2.02          |
# | total_timesteps    | 3584          |
# | value_loss         | 76.99907      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010231291 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0295       |
# | fps                | 2030          |
# | n_updates          | 29            |
# | policy_entropy     | 0.5975894     |
# | policy_loss        | 0.0005446983  |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 2.08          |
# | total_timesteps    | 3712          |
# | value_loss         | 70.11791      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.864393e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0123        |
# | fps                | 2080          |
# | n_updates          | 30            |
# | policy_entropy     | 0.5721627     |
# | policy_loss        | -0.0014841857 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 2.15          |
# | total_timesteps    | 3840          |
# | value_loss         | 60.295795     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0001478426 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.119       |
# | fps                | 2049         |
# | n_updates          | 31           |
# | policy_entropy     | 0.59265774   |
# | policy_loss        | 0.0049020625 |
# | serial_timesteps   | 3968         |
# | time_elapsed       | 2.21         |
# | total_timesteps    | 3968         |
# | value_loss         | 96.03307     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0019846393 |
# | clipfrac           | 0.013671875  |
# | explained_variance | 0.0622       |
# | fps                | 2081         |
# | n_updates          | 32           |
# | policy_entropy     | 0.59066194   |
# | policy_loss        | 0.009572472  |
# | serial_timesteps   | 4096         |
# | time_elapsed       | 2.27         |
# | total_timesteps    | 4096         |
# | value_loss         | 68.53476     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 4.5730125e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.221         |
# | fps                | 2070          |
# | n_updates          | 33            |
# | policy_entropy     | 0.602423      |
# | policy_loss        | 0.00064909505 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 2.33          |
# | total_timesteps    | 4224          |
# | value_loss         | 71.06869      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.7179077e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00779       |
# | fps                | 2197          |
# | n_updates          | 34            |
# | policy_entropy     | 0.59589267    |
# | policy_loss        | -0.0007897238 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 2.39          |
# | total_timesteps    | 4352          |
# | value_loss         | 72.50636      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009071587 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.13         |
# | fps                | 2196         |
# | n_updates          | 35           |
# | policy_entropy     | 0.60743433   |
# | policy_loss        | -0.005567502 |
# | serial_timesteps   | 4480         |
# | time_elapsed       | 2.45         |
# | total_timesteps    | 4480         |
# | value_loss         | 66.82593     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 6.9681904e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00617        |
# | fps                | 2155           |
# | n_updates          | 36             |
# | policy_entropy     | 0.5841716      |
# | policy_loss        | -0.00018501875 |
# | serial_timesteps   | 4608           |
# | time_elapsed       | 2.51           |
# | total_timesteps    | 4608           |
# | value_loss         | 59.67779       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.8665035e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0531        |
# | fps                | 2196          |
# | n_updates          | 37            |
# | policy_entropy     | 0.61305106    |
# | policy_loss        | -0.0009970277 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 2.57          |
# | total_timesteps    | 4736          |
# | value_loss         | 64.34942      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016899555 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.246         |
# | fps                | 2247          |
# | n_updates          | 38            |
# | policy_entropy     | 0.62293494    |
# | policy_loss        | -0.0018464476 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 2.63          |
# | total_timesteps    | 4864          |
# | value_loss         | 66.96263      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0022060021 |
# | clipfrac           | 0.013671875  |
# | explained_variance | 0.269        |
# | fps                | 2210         |
# | n_updates          | 39           |
# | policy_entropy     | 0.6023403    |
# | policy_loss        | -0.01098668  |
# | serial_timesteps   | 4992         |
# | time_elapsed       | 2.69         |
# | total_timesteps    | 4992         |
# | value_loss         | 71.475006    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00016609374 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0563        |
# | fps                | 2174          |
# | n_updates          | 40            |
# | policy_entropy     | 0.5883062     |
# | policy_loss        | 0.0027496007  |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 2.75          |
# | total_timesteps    | 5120          |
# | value_loss         | 62.488224     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00049318507 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00772       |
# | fps                | 2183          |
# | n_updates          | 41            |
# | policy_entropy     | 0.5503297     |
# | policy_loss        | -0.0052704946 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 2.81          |
# | total_timesteps    | 5248          |
# | value_loss         | 38.83766      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00041482702 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.335         |
# | fps                | 2255          |
# | n_updates          | 42            |
# | policy_entropy     | 0.551235      |
# | policy_loss        | -0.0035660872 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 2.87          |
# | total_timesteps    | 5376          |
# | value_loss         | 67.94106      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00015188463  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.353          |
# | fps                | 2191           |
# | n_updates          | 43             |
# | policy_entropy     | 0.55981666     |
# | policy_loss        | -0.00029956375 |
# | serial_timesteps   | 5504           |
# | time_elapsed       | 2.92           |
# | total_timesteps    | 5504           |
# | value_loss         | 83.927925      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 9.215385e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.334        |
# | fps                | 2282         |
# | n_updates          | 44           |
# | policy_entropy     | 0.5934737    |
# | policy_loss        | 0.0007707606 |
# | serial_timesteps   | 5632         |
# | time_elapsed       | 2.98         |
# | total_timesteps    | 5632         |
# | value_loss         | 62.402096    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 9.903871e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.168         |
# | fps                | 2160          |
# | n_updates          | 45            |
# | policy_entropy     | 0.6000468     |
# | policy_loss        | 0.00013828947 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 3.04          |
# | total_timesteps    | 5760          |
# | value_loss         | 65.28656      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.6607696e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0889        |
# | fps                | 1918          |
# | n_updates          | 46            |
# | policy_entropy     | 0.5969381     |
# | policy_loss        | -0.0010199399 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 3.1           |
# | total_timesteps    | 5888          |
# | value_loss         | 65.18058      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6452746e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0131       |
# | fps                | 2001          |
# | n_updates          | 47            |
# | policy_entropy     | 0.5884802     |
# | policy_loss        | 0.00056145503 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 3.17          |
# | total_timesteps    | 6016          |
# | value_loss         | 63.17397      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.0382256e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.115        |
# | fps                | 2096          |
# | n_updates          | 48            |
# | policy_entropy     | 0.5923785     |
# | policy_loss        | 0.00060610706 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 3.23          |
# | total_timesteps    | 6144          |
# | value_loss         | 78.90149      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 9.362937e-06 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0781       |
# | fps                | 2052         |
# | n_updates          | 49           |
# | policy_entropy     | 0.56441087   |
# | policy_loss        | 0.0007076891 |
# | serial_timesteps   | 6272         |
# | time_elapsed       | 3.29         |
# | total_timesteps    | 6272         |
# | value_loss         | 60.552055    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 7.240726e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0552        |
# | fps                | 2020          |
# | n_updates          | 50            |
# | policy_entropy     | 0.56271213    |
# | policy_loss        | -0.0027413738 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 3.36          |
# | total_timesteps    | 6400          |
# | value_loss         | 57.580433     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00038871507 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.261         |
# | fps                | 2069          |
# | n_updates          | 51            |
# | policy_entropy     | 0.5960201     |
# | policy_loss        | -0.0015436632 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 3.42          |
# | total_timesteps    | 6528          |
# | value_loss         | 58.724148     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.134345e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.2           |
# | fps                | 2117          |
# | n_updates          | 52            |
# | policy_entropy     | 0.59926504    |
# | policy_loss        | 0.00033817894 |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 3.48          |
# | total_timesteps    | 6656          |
# | value_loss         | 79.79548      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.7851316e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.235         |
# | fps                | 2216          |
# | n_updates          | 53            |
# | policy_entropy     | 0.60081184    |
# | policy_loss        | 4.363677e-05  |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 3.54          |
# | total_timesteps    | 6784          |
# | value_loss         | 67.212204     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018590526 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.217         |
# | fps                | 2037          |
# | n_updates          | 54            |
# | policy_entropy     | 0.56371224    |
# | policy_loss        | -0.0013691268 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 3.6           |
# | total_timesteps    | 6912          |
# | value_loss         | 64.550224     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001532583  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0314       |
# | fps                | 2055          |
# | n_updates          | 55            |
# | policy_entropy     | 0.5761605     |
# | policy_loss        | -0.0013531614 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 3.67          |
# | total_timesteps    | 7040          |
# | value_loss         | 40.29498      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.4121552e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.111         |
# | fps                | 2021          |
# | n_updates          | 56            |
# | policy_entropy     | 0.582173      |
# | policy_loss        | -0.0018692137 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 3.73          |
# | total_timesteps    | 7168          |
# | value_loss         | 78.872574     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.218419e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.134         |
# | fps                | 2033          |
# | n_updates          | 57            |
# | policy_entropy     | 0.57330436    |
# | policy_loss        | -0.0010490519 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 3.79          |
# | total_timesteps    | 7296          |
# | value_loss         | 76.85392      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.7160435e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0995        |
# | fps                | 2048          |
# | n_updates          | 58            |
# | policy_entropy     | 0.6015968     |
# | policy_loss        | 0.0010844243  |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 3.86          |
# | total_timesteps    | 7424          |
# | value_loss         | 56.913044     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 8.750143e-06 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.206        |
# | fps                | 2006         |
# | n_updates          | 59           |
# | policy_entropy     | 0.54748666   |
# | policy_loss        | -0.000446702 |
# | serial_timesteps   | 7552         |
# | time_elapsed       | 3.92         |
# | total_timesteps    | 7552         |
# | value_loss         | 51.3822      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 4.6395115e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.329         |
# | fps                | 2001          |
# | n_updates          | 60            |
# | policy_entropy     | 0.55084133    |
# | policy_loss        | -0.0011351286 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 3.98          |
# | total_timesteps    | 7680          |
# | value_loss         | 51.042236     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0001006188 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.317        |
# | fps                | 1992         |
# | n_updates          | 61           |
# | policy_entropy     | 0.5690791    |
# | policy_loss        | -0.004622768 |
# | serial_timesteps   | 7808         |
# | time_elapsed       | 4.05         |
# | total_timesteps    | 7808         |
# | value_loss         | 70.788605    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00019571932 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.208         |
# | fps                | 2030          |
# | n_updates          | 62            |
# | policy_entropy     | 0.572526      |
# | policy_loss        | 0.001921905   |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 4.11          |
# | total_timesteps    | 7936          |
# | value_loss         | 54.102066     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.4456832e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.281          |
# | fps                | 2075           |
# | n_updates          | 63             |
# | policy_entropy     | 0.60265934     |
# | policy_loss        | -0.00065618614 |
# | serial_timesteps   | 8064           |
# | time_elapsed       | 4.18           |
# | total_timesteps    | 8064           |
# | value_loss         | 73.70551       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.5740012e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.551         |
# | fps                | 2051          |
# | n_updates          | 64            |
# | policy_entropy     | 0.5781649     |
# | policy_loss        | -0.0005135406 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 4.24          |
# | total_timesteps    | 8192          |
# | value_loss         | 46.748714     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.3386601e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.297         |
# | fps                | 2035          |
# | n_updates          | 65            |
# | policy_entropy     | 0.5625241     |
# | policy_loss        | 0.0003833708  |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 4.3           |
# | total_timesteps    | 8320          |
# | value_loss         | 44.312023     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.3534963e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.22          |
# | fps                | 2009          |
# | n_updates          | 66            |
# | policy_entropy     | 0.5605403     |
# | policy_loss        | 3.882684e-06  |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 4.37          |
# | total_timesteps    | 8448          |
# | value_loss         | 72.09869      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014557314 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0774        |
# | fps                | 1962          |
# | n_updates          | 67            |
# | policy_entropy     | 0.5941374     |
# | policy_loss        | -0.0043891463 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 4.43          |
# | total_timesteps    | 8576          |
# | value_loss         | 73.96138      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.004414e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0426       |
# | fps                | 2017          |
# | n_updates          | 68            |
# | policy_entropy     | 0.56288636    |
# | policy_loss        | -0.0026038145 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 4.5           |
# | total_timesteps    | 8704          |
# | value_loss         | 57.509163     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.1061803e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0714       |
# | fps                | 2058          |
# | n_updates          | 69            |
# | policy_entropy     | 0.5889911     |
# | policy_loss        | -0.0012128929 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 4.56          |
# | total_timesteps    | 8832          |
# | value_loss         | 54.019547     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.5299443e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.176        |
# | fps                | 2055          |
# | n_updates          | 70            |
# | policy_entropy     | 0.5944807     |
# | policy_loss        | -0.0001125125 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 4.62          |
# | total_timesteps    | 8960          |
# | value_loss         | 73.58881      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.490847e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00182      |
# | fps                | 2015          |
# | n_updates          | 71            |
# | policy_entropy     | 0.57060987    |
# | policy_loss        | -0.0012018072 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 4.69          |
# | total_timesteps    | 9088          |
# | value_loss         | 52.329533     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00034457716 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0518        |
# | fps                | 2035          |
# | n_updates          | 72            |
# | policy_entropy     | 0.5745921     |
# | policy_loss        | -0.008406919  |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 4.75          |
# | total_timesteps    | 9216          |
# | value_loss         | 52.148678     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.083362e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.163          |
# | fps                | 2049           |
# | n_updates          | 73             |
# | policy_entropy     | 0.57828015     |
# | policy_loss        | -0.00016871816 |
# | serial_timesteps   | 9344           |
# | time_elapsed       | 4.82           |
# | total_timesteps    | 9344           |
# | value_loss         | 69.11831       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0011163377  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.457         |
# | fps                | 2062          |
# | n_updates          | 74            |
# | policy_entropy     | 0.59463316    |
# | policy_loss        | -0.0006717035 |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 4.88          |
# | total_timesteps    | 9472          |
# | value_loss         | 68.52965      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0052232444  |
# | clipfrac           | 0.0859375     |
# | explained_variance | -0.23         |
# | fps                | 2020          |
# | n_updates          | 75            |
# | policy_entropy     | 0.5812413     |
# | policy_loss        | -0.0025587878 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 4.94          |
# | total_timesteps    | 9600          |
# | value_loss         | 74.02348      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014457766  |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.0663        |
# | fps                | 2042          |
# | n_updates          | 76            |
# | policy_entropy     | 0.5678038     |
# | policy_loss        | -0.0029389872 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 5.01          |
# | total_timesteps    | 9728          |
# | value_loss         | 51.555126     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6794907e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.164        |
# | fps                | 2048          |
# | n_updates          | 77            |
# | policy_entropy     | 0.58355826    |
# | policy_loss        | -0.000497211  |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 5.07          |
# | total_timesteps    | 9856          |
# | value_loss         | 70.1087       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020406484  |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.0887        |
# | fps                | 1949          |
# | n_updates          | 78            |
# | policy_entropy     | 0.5598179     |
# | policy_loss        | -0.0032142473 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 5.13          |
# | total_timesteps    | 9984          |
# | value_loss         | 50.312126     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 8.798666e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0819       |
# | fps                | 2005         |
# | n_updates          | 79           |
# | policy_entropy     | 0.5819344    |
# ...
# | approxkl           | 6.0067314e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.463         |
# | fps                | 2033          |
# | n_updates          | 176           |
# | policy_entropy     | 0.59735173    |
# | policy_loss        | 0.0003350383  |
# | serial_timesteps   | 22528         |
# | time_elapsed       | 11.3          |
# | total_timesteps    | 22528         |
# | value_loss         | 51.633873     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 7.387003e-06 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.00924     |
# | fps                | 2074         |
# | n_updates          | 177          |
# | policy_entropy     | 0.58131313   |
# | policy_loss        | 6.235938e-05 |
# | serial_timesteps   | 22656        |
# | time_elapsed       | 11.4         |
# | total_timesteps    | 22656        |
# | value_loss         | 32.96526     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0006421534 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.474        |
# | fps                | 2117         |
# | n_updates          | 178          |
# | policy_entropy     | 0.5872498    |
# | policy_loss        | -0.004871863 |
# | serial_timesteps   | 22784        |
# | time_elapsed       | 11.4         |
# | total_timesteps    | 22784        |
# | value_loss         | 44.03624     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 6.2300955e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000826      |
# | fps                | 2094          |
# | n_updates          | 179           |
# | policy_entropy     | 0.55480397    |
# | policy_loss        | -0.0017423632 |
# | serial_timesteps   | 22912         |
# | time_elapsed       | 11.5          |
# | total_timesteps    | 22912         |
# | value_loss         | 69.779366     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000121742705 |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00091       |
# | fps                | 2032           |
# | n_updates          | 180            |
# | policy_entropy     | 0.5825325      |
# | policy_loss        | -0.0009927205  |
# | serial_timesteps   | 23040          |
# | time_elapsed       | 11.6           |
# | total_timesteps    | 23040          |
# | value_loss         | 71.567505      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.5573568e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.328          |
# | fps                | 2049           |
# | n_updates          | 181            |
# | policy_entropy     | 0.5973872      |
# | policy_loss        | -0.00015046773 |
# | serial_timesteps   | 23168          |
# | time_elapsed       | 11.6           |
# | total_timesteps    | 23168          |
# | value_loss         | 53.785763      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 5.959804e-06 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.106        |
# | fps                | 2051         |
# | n_updates          | 182          |
# | policy_entropy     | 0.57968587   |
# | policy_loss        | 6.208068e-05 |
# | serial_timesteps   | 23296        |
# | time_elapsed       | 11.7         |
# | total_timesteps    | 23296        |
# | value_loss         | 31.07421     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0001337235  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0575        |
# | fps                | 2051          |
# | n_updates          | 183           |
# | policy_entropy     | 0.5877489     |
# | policy_loss        | -0.0005008504 |
# | serial_timesteps   | 23424         |
# | time_elapsed       | 11.7          |
# | total_timesteps    | 23424         |
# | value_loss         | 69.49396      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.9732843e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.58          |
# | fps                | 2121          |
# | n_updates          | 184           |
# | policy_entropy     | 0.5655151     |
# | policy_loss        | 0.0002669365  |
# | serial_timesteps   | 23552         |
# | time_elapsed       | 11.8          |
# | total_timesteps    | 23552         |
# | value_loss         | 28.751114     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013778555 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.208         |
# | fps                | 2113          |
# | n_updates          | 185           |
# | policy_entropy     | 0.6030467     |
# | policy_loss        | -0.0030534933 |
# | serial_timesteps   | 23680         |
# | time_elapsed       | 11.9          |
# | total_timesteps    | 23680         |
# | value_loss         | 61.53164      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.0933406e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.135         |
# | fps                | 2098          |
# | n_updates          | 186           |
# | policy_entropy     | 0.5664155     |
# | policy_loss        | -0.0017117149 |
# | serial_timesteps   | 23808         |
# | time_elapsed       | 11.9          |
# | total_timesteps    | 23808         |
# | value_loss         | 65.31292      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.3613596e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0557       |
# | fps                | 2051          |
# | n_updates          | 187           |
# | policy_entropy     | 0.57132506    |
# | policy_loss        | 0.00021866604 |
# | serial_timesteps   | 23936         |
# | time_elapsed       | 12            |
# | total_timesteps    | 23936         |
# | value_loss         | 30.409382     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00048773066 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00258      |
# | fps                | 2071          |
# | n_updates          | 188           |
# | policy_entropy     | 0.5390765     |
# | policy_loss        | -0.0047777756 |
# | serial_timesteps   | 24064         |
# | time_elapsed       | 12.1          |
# | total_timesteps    | 24064         |
# | value_loss         | 76.28365      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.7458063e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00163       |
# | fps                | 1934          |
# | n_updates          | 189           |
# | policy_entropy     | 0.585637      |
# | policy_loss        | 0.00035679433 |
# | serial_timesteps   | 24192         |
# | time_elapsed       | 12.1          |
# | total_timesteps    | 24192         |
# | value_loss         | 78.90079      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014187483 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00102      |
# | fps                | 1987          |
# | n_updates          | 190           |
# | policy_entropy     | 0.5858406     |
# | policy_loss        | -0.0041749603 |
# | serial_timesteps   | 24320         |
# | time_elapsed       | 12.2          |
# | total_timesteps    | 24320         |
# | value_loss         | 74.935265     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020957654 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0815        |
# | fps                | 2079          |
# | n_updates          | 191           |
# | policy_entropy     | 0.5523234     |
# | policy_loss        | -0.0056037214 |
# | serial_timesteps   | 24448         |
# | time_elapsed       | 12.2          |
# | total_timesteps    | 24448         |
# | value_loss         | 74.27128      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.2708095e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0149        |
# | fps                | 2091          |
# | n_updates          | 192           |
# | policy_entropy     | 0.6046599     |
# | policy_loss        | 0.00023277535 |
# | serial_timesteps   | 24576         |
# | time_elapsed       | 12.3          |
# | total_timesteps    | 24576         |
# | value_loss         | 28.975706     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00067923754 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.245         |
# | fps                | 2127          |
# | n_updates          | 193           |
# | policy_entropy     | 0.60824704    |
# | policy_loss        | -0.0011926482 |
# | serial_timesteps   | 24704         |
# | time_elapsed       | 12.4          |
# | total_timesteps    | 24704         |
# | value_loss         | 59.94696      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.0469517e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00456       |
# | fps                | 2055           |
# | n_updates          | 194            |
# | policy_entropy     | 0.56176114     |
# | policy_loss        | -0.00035520026 |
# | serial_timesteps   | 24832          |
# | time_elapsed       | 12.4           |
# | total_timesteps    | 24832          |
# | value_loss         | 28.429623      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00010858664  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.037         |
# | fps                | 2093           |
# | n_updates          | 195            |
# | policy_entropy     | 0.60137033     |
# | policy_loss        | -0.00025769882 |
# | serial_timesteps   | 24960          |
# | time_elapsed       | 12.5           |
# | total_timesteps    | 24960          |
# | value_loss         | 28.298307      |
# ---------------------------------------
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13e19cdd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13e19cdd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13e19cdd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13e19cdd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13e81d090>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13e81d090>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13e81d090>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x13e81d090>>: AttributeError: module 'gast' has no attribute 'Num'
# /Users/mats/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-cefa98f79cf9> in <module>
#      19 obs = env.reset()
#      20 while True:
# ---> 21     action, _states = model.predict(obs)
#      22     obs, rewards, dones, info = env.step(action)
#      23     env.render()
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     817
#     818         observation = observation.reshape((-1,) + self.observation_space.shape)
# --> 819         actions, _, states, _ = self.step(observation, state, mask, deterministic=deterministic)
#     820
#     821         clipped_actions = actions
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py in step(self, obs, state, mask, deterministic)
#     574         else:
#     575             action, value, neglogp = self.sess.run([self.action, self.value_flat, self.neglogp],
# --> 576                                                    {self.obs_ph: obs})
#     577         return action, value, self.initial_state, neglogp
#     578
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import gym

# %%
import gym_gvgai

# %%
[env.id for env in gym.envs.registry.all() if env.id.startswith('gvgai')]
# Out:
# ['gvgai-themole-lvl0-v0',
#  'gvgai-themole-lvl1-v0',
#  'gvgai-themole-lvl2-v0',
#  'gvgai-themole-lvl3-v0',
#  'gvgai-themole-lvl4-v0',
#  'gvgai-chopper-lvl0-v0',
#  'gvgai-chopper-lvl1-v0',
#  'gvgai-chopper-lvl2-v0',
#  'gvgai-chopper-lvl3-v0',
#  'gvgai-chopper-lvl4-v0',
#  'gvgai-bait-lvl0-v0',
#  'gvgai-bait-lvl1-v0',
#  'gvgai-bait-lvl2-v0',
#  'gvgai-bait-lvl3-v0',
#  'gvgai-bait-lvl4-v0',
#  'gvgai-lemmings-lvl0-v0',
#  'gvgai-lemmings-lvl1-v0',
#  'gvgai-lemmings-lvl2-v0',
#  'gvgai-lemmings-lvl3-v0',
#  'gvgai-lemmings-lvl4-v0',
#  'gvgai-cookmepasta-lvl0-v0',
#  'gvgai-cookmepasta-lvl1-v0',
#  'gvgai-cookmepasta-lvl2-v0',
#  'gvgai-cookmepasta-lvl3-v0',
#  'gvgai-cookmepasta-lvl4-v0',
#  'gvgai-seaquest-lvl0-v0',
#  'gvgai-seaquest-lvl1-v0',
#  'gvgai-seaquest-lvl2-v0',
#  'gvgai-seaquest-lvl3-v0',
#  'gvgai-seaquest-lvl4-v0',
#  'gvgai-pokemon-lvl0-v0',
#  'gvgai-pokemon-lvl1-v0',
#  'gvgai-pokemon-lvl2-v0',
#  'gvgai-pokemon-lvl3-v0',
#  'gvgai-pokemon-lvl4-v0',
#  'gvgai-factorymanager-lvl0-v0',
#  'gvgai-factorymanager-lvl1-v0',
#  'gvgai-factorymanager-lvl2-v0',
#  'gvgai-factorymanager-lvl3-v0',
#  'gvgai-factorymanager-lvl4-v0',
#  'gvgai-roguelike-lvl0-v0',
#  'gvgai-roguelike-lvl1-v0',
#  'gvgai-roguelike-lvl2-v0',
#  'gvgai-roguelike-lvl3-v0',
#  'gvgai-roguelike-lvl4-v0',
#  'gvgai-thesnowman-lvl0-v0',
#  'gvgai-thesnowman-lvl1-v0',
#  'gvgai-thesnowman-lvl2-v0',
#  'gvgai-thesnowman-lvl3-v0',
#  'gvgai-thesnowman-lvl4-v0',
#  'gvgai-boloadventures-lvl0-v0',
#  'gvgai-boloadventures-lvl1-v0',
#  'gvgai-boloadventures-lvl2-v0',
#  'gvgai-boloadventures-lvl3-v0',
#  'gvgai-boloadventures-lvl4-v0',
#  'gvgai-thecitadel-lvl0-v0',
#  'gvgai-thecitadel-lvl1-v0',
#  'gvgai-thecitadel-lvl2-v0',
#  'gvgai-thecitadel-lvl3-v0',
#  'gvgai-thecitadel-lvl4-v0',
#  'gvgai-beltmanager-lvl0-v0',
#  'gvgai-beltmanager-lvl1-v0',
#  'gvgai-beltmanager-lvl2-v0',
#  'gvgai-beltmanager-lvl3-v0',
#  'gvgai-beltmanager-lvl4-v0',
#  'gvgai-labyrinth-lvl0-v0',
#  'gvgai-labyrinth-lvl1-v0',
#  'gvgai-labyrinth-lvl2-v0',
#  'gvgai-labyrinth-lvl3-v0',
#  'gvgai-labyrinth-lvl4-v0',
#  'gvgai-investdie-lvl0-v0',
#  'gvgai-cakybaky-lvl0-v0',
#  'gvgai-cakybaky-lvl1-v0',
#  'gvgai-cakybaky-lvl2-v0',
#  'gvgai-cakybaky-lvl3-v0',
#  'gvgai-cakybaky-lvl4-v0',
#  'gvgai-roadfighter-lvl0-v0',
#  'gvgai-roadfighter-lvl1-v0',
#  'gvgai-roadfighter-lvl2-v0',
#  'gvgai-roadfighter-lvl3-v0',
#  'gvgai-roadfighter-lvl4-v0',
#  'gvgai-sheriff-lvl0-v0',
#  'gvgai-sheriff-lvl1-v0',
#  'gvgai-sheriff-lvl2-v0',
#  'gvgai-sheriff-lvl3-v0',
#  'gvgai-sheriff-lvl4-v0',
#  'gvgai-superman-lvl0-v0',
#  'gvgai-superman-lvl1-v0',
#  'gvgai-superman-lvl2-v0',
#  'gvgai-superman-lvl3-v0',
#  'gvgai-superman-lvl4-v0',
#  'gvgai-bomber-lvl0-v0',
#  'gvgai-bomber-lvl1-v0',
#  'gvgai-bomber-lvl2-v0',
#  'gvgai-bomber-lvl3-v0',
#  'gvgai-bomber-lvl4-v0',
#  'gvgai-modality-lvl0-v0',
#  'gvgai-modality-lvl1-v0',
#  'gvgai-modality-lvl2-v0',
#  'gvgai-modality-lvl3-v0',
#  'gvgai-modality-lvl4-v0',
#  'gvgai-frogs-lvl0-v0',
#  'gvgai-frogs-lvl1-v0',
#  'gvgai-frogs-lvl2-v0',
#  'gvgai-frogs-lvl3-v0',
#  'gvgai-frogs-lvl4-v0',
#  'gvgai-flower-lvl0-v0',
#  'gvgai-brainman-lvl0-v0',
#  'gvgai-brainman-lvl1-v0',
#  'gvgai-brainman-lvl2-v0',
#  'gvgai-brainman-lvl3-v0',
#  'gvgai-brainman-lvl4-v0',
#  'gvgai-enemycitadel-lvl0-v0',
#  'gvgai-enemycitadel-lvl1-v0',
#  'gvgai-enemycitadel-lvl2-v0',
#  'gvgai-enemycitadel-lvl3-v0',
#  'gvgai-enemycitadel-lvl4-v0',
#  'gvgai-testgame2-lvl0-v0',
#  'gvgai-testgame2-lvl1-v0',
#  'gvgai-shipwreck-lvl0-v0',
#  'gvgai-shipwreck-lvl1-v0',
#  'gvgai-shipwreck-lvl2-v0',
#  'gvgai-shipwreck-lvl3-v0',
#  'gvgai-shipwreck-lvl4-v0',
#  'gvgai-fireman-lvl0-v0',
#  'gvgai-fireman-lvl1-v0',
#  'gvgai-fireman-lvl2-v0',
#  'gvgai-fireman-lvl3-v0',
#  'gvgai-fireman-lvl4-v0',
#  'gvgai-eighthpassenger-lvl0-v0',
#  'gvgai-eighthpassenger-lvl1-v0',
#  'gvgai-eighthpassenger-lvl2-v0',
#  'gvgai-eighthpassenger-lvl3-v0',
#  'gvgai-eighthpassenger-lvl4-v0',
#  'gvgai-surround-lvl0-v0',
#  'gvgai-surround-lvl1-v0',
#  'gvgai-surround-lvl2-v0',
#  'gvgai-surround-lvl3-v0',
#  'gvgai-surround-lvl4-v0',
#  'gvgai-catapults-lvl0-v0',
#  'gvgai-catapults-lvl1-v0',
#  'gvgai-catapults-lvl2-v0',
#  'gvgai-catapults-lvl3-v0',
#  'gvgai-catapults-lvl4-v0',
#  'gvgai-assemblyline-lvl0-v0',
#  'gvgai-assemblyline-lvl1-v0',
#  'gvgai-assemblyline-lvl2-v0',
#  'gvgai-assemblyline-lvl3-v0',
#  'gvgai-assemblyline-lvl4-v0',
#  'gvgai-cec1-lvl0-v0',
#  'gvgai-cec1-lvl1-v0',
#  'gvgai-chainreaction-lvl0-v0',
#  'gvgai-chainreaction-lvl1-v0',
#  'gvgai-chainreaction-lvl2-v0',
#  'gvgai-chainreaction-lvl3-v0',
#  'gvgai-chainreaction-lvl4-v0',
#  'gvgai-missilecommand-lvl0-v0',
#  'gvgai-missilecommand-lvl1-v0',
#  'gvgai-missilecommand-lvl2-v0',
#  'gvgai-missilecommand-lvl3-v0',
#  'gvgai-missilecommand-lvl4-v0',
#  'gvgai-firestorms-lvl0-v0',
#  'gvgai-firestorms-lvl1-v0',
#  'gvgai-firestorms-lvl2-v0',
#  'gvgai-firestorms-lvl3-v0',
#  'gvgai-firestorms-lvl4-v0',
#  'gvgai-blacksmoke-lvl0-v0',
#  'gvgai-blacksmoke-lvl1-v0',
#  'gvgai-blacksmoke-lvl2-v0',
#  'gvgai-blacksmoke-lvl3-v0',
#  'gvgai-blacksmoke-lvl4-v0',
#  'gvgai-survivezombies-lvl0-v0',
#  'gvgai-survivezombies-lvl1-v0',
#  'gvgai-survivezombies-lvl2-v0',
#  'gvgai-survivezombies-lvl3-v0',
#  'gvgai-survivezombies-lvl4-v0',
#  'gvgai-solarfox-lvl0-v0',
#  'gvgai-solarfox-lvl1-v0',
#  'gvgai-solarfox-lvl2-v0',
#  'gvgai-solarfox-lvl3-v0',
#  'gvgai-solarfox-lvl4-v0',
#  'gvgai-mirrors-lvl0-v0',
#  'gvgai-mirrors-lvl1-v0',
#  'gvgai-mirrors-lvl2-v0',
#  'gvgai-mirrors-lvl3-v0',
#  'gvgai-mirrors-lvl4-v0',
#  'gvgai-colourescape-lvl0-v0',
#  'gvgai-colourescape-lvl1-v0',
#  'gvgai-colourescape-lvl2-v0',
#  'gvgai-colourescape-lvl3-v0',
#  'gvgai-colourescape-lvl4-v0',
#  'gvgai-intersection-lvl0-v0',
#  'gvgai-intersection-lvl1-v0',
#  'gvgai-intersection-lvl2-v0',
#  'gvgai-intersection-lvl3-v0',
#  'gvgai-intersection-lvl4-v0',
#  'gvgai-portals-lvl0-v0',
#  'gvgai-portals-lvl1-v0',
#  'gvgai-portals-lvl2-v0',
#  'gvgai-portals-lvl3-v0',
#  'gvgai-portals-lvl4-v0',
#  'gvgai-chase-lvl0-v0',
#  'gvgai-chase-lvl1-v0',
#  'gvgai-chase-lvl2-v0',
#  'gvgai-chase-lvl3-v0',
#  'gvgai-chase-lvl4-v0',
#  'gvgai-zelda-lvl0-v0',
#  'gvgai-zelda-lvl1-v0',
#  'gvgai-zelda-lvl2-v0',
#  'gvgai-zelda-lvl3-v0',
#  'gvgai-zelda-lvl4-v0',
#  'gvgai-eggomania-lvl0-v0',
#  'gvgai-eggomania-lvl1-v0',
#  'gvgai-eggomania-lvl2-v0',
#  'gvgai-eggomania-lvl3-v0',
#  'gvgai-eggomania-lvl4-v0',
#  'gvgai-sokoban-lvl0-v0',
#  'gvgai-sokoban-lvl1-v0',
#  'gvgai-sokoban-lvl2-v0',
#  'gvgai-sokoban-lvl3-v0',
#  'gvgai-sokoban-lvl4-v0',
#  'gvgai-overload-lvl0-v0',
#  'gvgai-overload-lvl1-v0',
#  'gvgai-overload-lvl2-v0',
#  'gvgai-overload-lvl3-v0',
#  'gvgai-overload-lvl4-v0',
#  'gvgai-invest-lvl0-v0',
#  'gvgai-hungrybirds-lvl0-v0',
#  'gvgai-hungrybirds-lvl1-v0',
#  'gvgai-hungrybirds-lvl2-v0',
#  'gvgai-hungrybirds-lvl3-v0',
#  'gvgai-hungrybirds-lvl4-v0',
#  'gvgai-wrapsokoban-lvl0-v0',
#  'gvgai-wrapsokoban-lvl1-v0',
#  'gvgai-wrapsokoban-lvl2-v0',
#  'gvgai-wrapsokoban-lvl3-v0',
#  'gvgai-wrapsokoban-lvl4-v0',
#  'gvgai-testgame3-lvl0-v0',
#  'gvgai-testgame3-lvl1-v0',
#  'gvgai-waves-lvl0-v0',
#  'gvgai-waves-lvl1-v0',
#  'gvgai-waves-lvl2-v0',
#  'gvgai-waves-lvl3-v0',
#  'gvgai-waves-lvl4-v0',
#  'gvgai-aliens-lvl0-v0',
#  'gvgai-aliens-lvl1-v0',
#  'gvgai-aliens-lvl2-v0',
#  'gvgai-aliens-lvl3-v0',
#  'gvgai-aliens-lvl4-v0',
#  'gvgai-butterflies-lvl0-v0',
#  'gvgai-butterflies-lvl1-v0',
#  'gvgai-butterflies-lvl2-v0',
#  'gvgai-butterflies-lvl3-v0',
#  'gvgai-butterflies-lvl4-v0',
#  'gvgai-realportals-lvl0-v0',
#  'gvgai-realportals-lvl1-v0',
#  'gvgai-realportals-lvl2-v0',
#  'gvgai-realportals-lvl3-v0',
#  'gvgai-realportals-lvl4-v0',
#  'gvgai-boulderchase-lvl0-v0',
#  'gvgai-boulderchase-lvl1-v0',
#  'gvgai-boulderchase-lvl2-v0',
#  'gvgai-boulderchase-lvl3-v0',
#  'gvgai-boulderchase-lvl4-v0',
#  'gvgai-avoidgeorge-lvl0-v0',
#  'gvgai-avoidgeorge-lvl1-v0',
#  'gvgai-avoidgeorge-lvl2-v0',
#  'gvgai-avoidgeorge-lvl3-v0',
#  'gvgai-avoidgeorge-lvl4-v0',
#  'gvgai-realsokoban-lvl0-v0',
#  'gvgai-realsokoban-lvl1-v0',
#  'gvgai-realsokoban-lvl2-v0',
#  'gvgai-realsokoban-lvl3-v0',
#  'gvgai-realsokoban-lvl4-v0',
#  'gvgai-vortex-lvl0-v0',
#  'gvgai-vortex-lvl1-v0',
#  'gvgai-vortex-lvl2-v0',
#  'gvgai-vortex-lvl3-v0',
#  'gvgai-vortex-lvl4-v0',
#  'gvgai-chipschallenge-lvl0-v0',
#  'gvgai-chipschallenge-lvl1-v0',
#  'gvgai-chipschallenge-lvl2-v0',
#  'gvgai-chipschallenge-lvl3-v0',
#  'gvgai-chipschallenge-lvl4-v0',
#  'gvgai-cec3-lvl0-v0',
#  'gvgai-cec3-lvl1-v0',
#  'gvgai-deceptizelda-lvl0-v0',
#  'gvgai-deceptizelda-lvl1-v0',
#  'gvgai-deceptizelda-lvl2-v0',
#  'gvgai-deceptizelda-lvl3-v0',
#  'gvgai-deceptizelda-lvl4-v0',
#  'gvgai-cops-lvl0-v0',
#  'gvgai-cops-lvl1-v0',
#  'gvgai-cops-lvl2-v0',
#  'gvgai-cops-lvl3-v0',
#  'gvgai-cops-lvl4-v0',
#  'gvgai-iceandfire-lvl0-v0',
#  'gvgai-iceandfire-lvl1-v0',
#  'gvgai-iceandfire-lvl2-v0',
#  'gvgai-iceandfire-lvl3-v0',
#  'gvgai-iceandfire-lvl4-v0',
#  'gvgai-racebet2-lvl0-v0',
#  'gvgai-racebet2-lvl1-v0',
#  'gvgai-racebet2-lvl2-v0',
#  'gvgai-racebet2-lvl3-v0',
#  'gvgai-racebet2-lvl4-v0',
#  'gvgai-x-racer-lvl0-v0',
#  'gvgai-x-racer-lvl1-v0',
#  'gvgai-x-racer-lvl2-v0',
#  'gvgai-x-racer-lvl3-v0',
#  'gvgai-x-racer-lvl4-v0',
#  'gvgai-islands-lvl0-v0',
#  'gvgai-islands-lvl1-v0',
#  'gvgai-islands-lvl2-v0',
#  'gvgai-islands-lvl3-v0',
#  'gvgai-islands-lvl4-v0',
#  'gvgai-doorkoban-lvl0-v0',
#  'gvgai-doorkoban-lvl1-v0',
#  'gvgai-doorkoban-lvl2-v0',
#  'gvgai-doorkoban-lvl3-v0',
#  'gvgai-doorkoban-lvl4-v0',
#  'gvgai-waferthinmintsexit-lvl0-v0',
#  'gvgai-escape-lvl0-v0',
#  'gvgai-escape-lvl1-v0',
#  'gvgai-escape-lvl2-v0',
#  'gvgai-escape-lvl3-v0',
#  'gvgai-escape-lvl4-v0',
#  'gvgai-ikaruga-lvl0-v0',
#  'gvgai-ikaruga-lvl1-v0',
#  'gvgai-ikaruga-lvl2-v0',
#  'gvgai-ikaruga-lvl3-v0',
#  'gvgai-ikaruga-lvl4-v0',
#  'gvgai-testgame1-lvl0-v0',
#  'gvgai-testgame1-lvl1-v0',
#  'gvgai-zenpuzzle-lvl0-v0',
#  'gvgai-zenpuzzle-lvl1-v0',
#  'gvgai-zenpuzzle-lvl2-v0',
#  'gvgai-zenpuzzle-lvl3-v0',
#  'gvgai-zenpuzzle-lvl4-v0',
#  'gvgai-sistersavior-lvl0-v0',
#  'gvgai-sistersavior-lvl1-v0',
#  'gvgai-racebet-lvl0-v0',
#  'gvgai-racebet-lvl1-v0',
#  'gvgai-racebet-lvl2-v0',
#  'gvgai-racebet-lvl3-v0',
#  'gvgai-racebet-lvl4-v0',
#  'gvgai-camelRace-lvl0-v0',
#  'gvgai-camelRace-lvl1-v0',
#  'gvgai-camelRace-lvl2-v0',
#  'gvgai-camelRace-lvl3-v0',
#  'gvgai-camelRace-lvl4-v0',
#  'gvgai-run-lvl0-v0',
#  'gvgai-run-lvl1-v0',
#  'gvgai-run-lvl2-v0',
#  'gvgai-run-lvl3-v0',
#  'gvgai-run-lvl4-v0',
#  'gvgai-pacman-lvl0-v0',
#  'gvgai-pacman-lvl1-v0',
#  'gvgai-pacman-lvl2-v0',
#  'gvgai-pacman-lvl3-v0',
#  'gvgai-pacman-lvl4-v0',
#  'gvgai-lasers-lvl0-v0',
#  'gvgai-lasers-lvl1-v0',
#  'gvgai-lasers-lvl2-v0',
#  'gvgai-lasers-lvl3-v0',
#  'gvgai-lasers-lvl4-v0',
#  'gvgai-killBillVol1-lvl0-v0',
#  'gvgai-killBillVol1-lvl1-v0',
#  'gvgai-killBillVol1-lvl2-v0',
#  'gvgai-killBillVol1-lvl3-v0',
#  'gvgai-killBillVol1-lvl4-v0',
#  'gvgai-theshepherd-lvl0-v0',
#  'gvgai-theshepherd-lvl1-v0',
#  'gvgai-theshepherd-lvl2-v0',
#  'gvgai-theshepherd-lvl3-v0',
#  'gvgai-theshepherd-lvl4-v0',
#  'gvgai-crossfire-lvl0-v0',
#  'gvgai-crossfire-lvl1-v0',
#  'gvgai-crossfire-lvl2-v0',
#  'gvgai-crossfire-lvl3-v0',
#  'gvgai-crossfire-lvl4-v0',
#  'gvgai-cec2-lvl0-v0',
#  'gvgai-cec2-lvl1-v0',
#  'gvgai-ghostbuster-lvl0-v0',
#  'gvgai-ghostbuster-lvl1-v0',
#  'gvgai-ghostbuster-lvl2-v0',
#  'gvgai-ghostbuster-lvl3-v0',
#  'gvgai-ghostbuster-lvl4-v0',
#  'gvgai-bomberman-lvl0-v0',
#  'gvgai-bomberman-lvl1-v0',
#  'gvgai-bomberman-lvl2-v0',
#  'gvgai-bomberman-lvl3-v0',
#  'gvgai-bomberman-lvl4-v0',
#  'gvgai-boulderdash-lvl0-v0',
#  'gvgai-boulderdash-lvl1-v0',
#  'gvgai-boulderdash-lvl2-v0',
#  'gvgai-boulderdash-lvl3-v0',
#  'gvgai-boulderdash-lvl4-v0',
#  'gvgai-rivers-lvl0-v0',
#  'gvgai-rivers-lvl1-v0',
#  'gvgai-rivers-lvl2-v0',
#  'gvgai-rivers-lvl3-v0',
#  'gvgai-rivers-lvl4-v0',
#  'gvgai-watergame-lvl0-v0',
#  'gvgai-watergame-lvl1-v0',
#  'gvgai-watergame-lvl2-v0',
#  'gvgai-watergame-lvl3-v0',
#  'gvgai-watergame-lvl4-v0',
#  'gvgai-infection-lvl0-v0',
#  'gvgai-infection-lvl1-v0',
#  'gvgai-infection-lvl2-v0',
#  'gvgai-infection-lvl3-v0',
#  'gvgai-infection-lvl4-v0',
#  'gvgai-gymkhana-lvl0-v0',
#  'gvgai-gymkhana-lvl1-v0',
#  'gvgai-gymkhana-lvl2-v0',
#  'gvgai-gymkhana-lvl3-v0',
#  'gvgai-gymkhana-lvl4-v0',
#  'gvgai-firecaster-lvl0-v0',
#  'gvgai-firecaster-lvl1-v0',
#  'gvgai-firecaster-lvl2-v0',
#  'gvgai-firecaster-lvl3-v0',
#  'gvgai-firecaster-lvl4-v0',
#  'gvgai-angelsdemons-lvl0-v0',
#  'gvgai-angelsdemons-lvl1-v0',
#  'gvgai-angelsdemons-lvl2-v0',
#  'gvgai-angelsdemons-lvl3-v0',
#  'gvgai-angelsdemons-lvl4-v0',
#  'gvgai-wildgunman-lvl0-v0',
#  'gvgai-wildgunman-lvl1-v0',
#  'gvgai-wildgunman-lvl2-v0',
#  'gvgai-wildgunman-lvl3-v0',
#  'gvgai-wildgunman-lvl4-v0',
#  'gvgai-witnessprotected-lvl0-v0',
#  'gvgai-witnessprotected-lvl1-v0',
#  'gvgai-witnessprotected-lvl2-v0',
#  'gvgai-witnessprotected-lvl3-v0',
#  'gvgai-witnessprotected-lvl4-v0',
#  'gvgai-digdug-lvl0-v0',
#  'gvgai-digdug-lvl1-v0',
#  'gvgai-digdug-lvl2-v0',
#  'gvgai-digdug-lvl3-v0',
#  'gvgai-digdug-lvl4-v0',
#  'gvgai-waferthinmints-lvl0-v0',
#  'gvgai-waitforbreakfast-lvl0-v0',
#  'gvgai-waitforbreakfast-lvl1-v0',
#  'gvgai-waitforbreakfast-lvl2-v0',
#  'gvgai-waitforbreakfast-lvl3-v0',
#  'gvgai-waitforbreakfast-lvl4-v0',
#  'gvgai-labyrinthdual-lvl0-v0',
#  'gvgai-labyrinthdual-lvl1-v0',
#  'gvgai-labyrinthdual-lvl2-v0',
#  'gvgai-labyrinthdual-lvl3-v0',
#  'gvgai-labyrinthdual-lvl4-v0',
#  'gvgai-garbagecollector-lvl0-v0',
#  'gvgai-garbagecollector-lvl1-v0',
#  'gvgai-garbagecollector-lvl2-v0',
#  'gvgai-garbagecollector-lvl3-v0',
#  'gvgai-garbagecollector-lvl4-v0',
#  'gvgai-dungeon-lvl0-v0',
#  'gvgai-dungeon-lvl1-v0',
#  'gvgai-dungeon-lvl2-v0',
#  'gvgai-dungeon-lvl3-v0',
#  'gvgai-dungeon-lvl4-v0',
#  'gvgai-deflection-lvl0-v0',
#  'gvgai-deflection-lvl1-v0',
#  'gvgai-deflection-lvl2-v0',
#  'gvgai-deflection-lvl3-v0',
#  'gvgai-deflection-lvl4-v0',
#  'gvgai-tercio-lvl0-v0',
#  'gvgai-tercio-lvl1-v0',
#  'gvgai-tercio-lvl2-v0',
#  'gvgai-tercio-lvl3-v0',
#  'gvgai-tercio-lvl4-v0',
#  'gvgai-whackamole-lvl0-v0',
#  'gvgai-whackamole-lvl1-v0',
#  'gvgai-whackamole-lvl2-v0',
#  'gvgai-whackamole-lvl3-v0',
#  'gvgai-whackamole-lvl4-v0',
#  'gvgai-donkeykong-lvl0-v0',
#  'gvgai-donkeykong-lvl1-v0',
#  'gvgai-donkeykong-lvl2-v0',
#  'gvgai-donkeykong-lvl3-v0',
#  'gvgai-donkeykong-lvl4-v0',
#  'gvgai-defem-lvl0-v0',
#  'gvgai-defem-lvl1-v0',
#  'gvgai-defem-lvl2-v0',
#  'gvgai-defem-lvl3-v0',
#  'gvgai-defem-lvl4-v0',
#  'gvgai-jaws-lvl0-v0',
#  'gvgai-jaws-lvl1-v0',
#  'gvgai-jaws-lvl2-v0',
#  'gvgai-jaws-lvl3-v0',
#  'gvgai-jaws-lvl4-v0',
#  'gvgai-clusters-lvl0-v0',
#  'gvgai-clusters-lvl1-v0',
#  'gvgai-clusters-lvl2-v0',
#  'gvgai-clusters-lvl3-v0',
#  'gvgai-clusters-lvl4-v0',
#  'gvgai-painter-lvl0-v0',
#  'gvgai-painter-lvl1-v0',
#  'gvgai-painter-lvl2-v0',
#  'gvgai-painter-lvl3-v0',
#  'gvgai-painter-lvl4-v0',
#  'gvgai-lasers2-lvl0-v0',
#  'gvgai-lasers2-lvl1-v0',
#  'gvgai-lasers2-lvl2-v0',
#  'gvgai-lasers2-lvl3-v0',
#  'gvgai-lasers2-lvl4-v0',
#  'gvgai-defender-lvl0-v0',
#  'gvgai-defender-lvl1-v0',
#  'gvgai-defender-lvl2-v0',
#  'gvgai-defender-lvl3-v0',
#  'gvgai-defender-lvl4-v0',
#  'gvgai-plants-lvl0-v0',
#  'gvgai-plants-lvl1-v0',
#  'gvgai-plants-lvl2-v0',
#  'gvgai-plants-lvl3-v0',
#  'gvgai-plants-lvl4-v0',
#  'gvgai-freeway-lvl0-v0',
#  'gvgai-freeway-lvl1-v0',
#  'gvgai-freeway-lvl2-v0',
#  'gvgai-freeway-lvl3-v0',
#  'gvgai-freeway-lvl4-v0',
#  'gvgai-witnessprotection-lvl0-v0',
#  'gvgai-witnessprotection-lvl1-v0',
#  'gvgai-witnessprotection-lvl2-v0',
#  'gvgai-witnessprotection-lvl3-v0',
#  'gvgai-witnessprotection-lvl4-v0',
#  'gvgai-decepticoins-lvl0-v0',
#  'gvgai-decepticoins-lvl1-v0',
#  'gvgai-decepticoins-lvl2-v0',
#  'gvgai-decepticoins-lvl3-v0',
#  'gvgai-decepticoins-lvl4-v0',
#  'gvgai-plaqueattack-lvl0-v0',
#  'gvgai-plaqueattack-lvl1-v0',
#  'gvgai-plaqueattack-lvl2-v0',
#  'gvgai-plaqueattack-lvl3-v0',
#  'gvgai-plaqueattack-lvl4-v0']

# %%
import numpy as np

from stable_baselines.ddpg.policies import MlpPolicy
from stable_baselines.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise, AdaptiveParamNoiseSpec
from stable_baselines import DDPG

env = gym.make('MountainCarContinuous-v0')

# the noise objects for DDPG
n_actions = env.action_space.shape[-1]
param_noise = None
action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions), sigma=float(0.5) * np.ones(n_actions))

model = DDPG(MlpPolicy, env, verbose=1, param_noise=param_noise, action_noise=action_noise)
model.learn(total_timesteps=400000)
model.save("ddpg_mountain")

del model # remove to demonstrate saving and loading

model = DDPG.load("ddpg_mountain")

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mats/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/ddpg/ddpg.py:332: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/ddpg/policies.py:135: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x1468128d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x1468128d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x1468128d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x1468128d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/ddpg/policies.py:137: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x130df5310>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x130df5310>>: AssertionError: Bad argument number for Name: 3, expecting 4
# /Users/mats/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x130df5310>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x130df5310>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146801910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146801910>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146801910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146801910>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x145575f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x145575f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x145575f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x145575f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x146820e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x146820e50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x146820e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x146820e50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146820210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x147a8d610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x147a8d610>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x147a8d610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x147a8d610>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812550>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812550>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x147a246d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x147a246d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x147a246d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x147a246d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812550>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812550>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x146812510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x146812510>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x146812510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x146812510>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x146812510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14799d910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14799d910>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14799d910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x14799d910>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x1479c61d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x1479c61d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x1479c61d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x1479c61d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x10f774210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/ddpg/ddpg.py:412: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/mats/anaconda3/lib/python3.7/site-packages/stable_baselines/ddpg/ddpg.py:452: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# --------------------------------------
# | reference_Q_mean        | 0.0692   |
# | reference_Q_std         | 0.226    |
# | reference_action_mean   | 0.0153   |
# | reference_action_std    | 0.0573   |
# | reference_actor_Q_mean  | 0.0991   |
# | reference_actor_Q_std   | 0.224    |
# | rollout/Q_mean          | 0.0285   |
# | rollout/actions_mean    | -0.0227  |
# | rollout/actions_std     | 0.548    |
# | rollout/episode_steps   | 998      |
# | rollout/episodes        | 10       |
# | rollout/return          | -20.1    |
# | rollout/return_history  | -20.1    |
# | total/duration          | 13       |
# | total/episodes          | 10       |
# | total/epochs            | 1        |
# | total/steps             | 9998     |
# | total/steps_per_second  | 771      |
# | train/loss_actor        | -0.0934  |
# | train/loss_critic       | 1.34     |
# | train/param_noise_di... | 0        |
# --------------------------------------
#
# --------------------------------------
# | reference_Q_mean        | 0.0578   |
# | reference_Q_std         | 0.374    |
# | reference_action_mean   | -0.0721  |
# | reference_action_std    | 0.14     |
# | reference_actor_Q_mean  | 0.0925   |
# | reference_actor_Q_std   | 0.402    |
# | rollout/Q_mean          | 0.0369   |
# | rollout/actions_mean    | -0.145   |
# | rollout/actions_std     | 0.561    |
# | rollout/episode_steps   | 986      |
# | rollout/episodes        | 20       |
# | rollout/return          | -22.4    |
# | rollout/return_history  | -22.4    |
# | total/duration          | 26.7     |
# | total/episodes          | 20       |
# | total/epochs            | 1        |
# | total/steps             | 19998    |
# | total/steps_per_second  | 748      |
# | train/loss_actor        | -0.089   |
# | train/loss_critic       | 0.0085   |
# | train/param_noise_di... | 0        |
# --------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3cd516c1f9a5> in <module>
#      13
#      14 model = DDPG(MlpPolicy, env, verbose=1, param_noise=param_noise, action_noise=action_noise)
# ---> 15 model.learn(total_timesteps=400000)
#      16 model.save("ddpg_mountain")
#      17
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/ddpg/ddpg.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, replay_wrapper)
#     971                                     self.num_timesteps - self.nb_rollout_steps)
#     972
# --> 973                             critic_loss, actor_loss = self._train_step(step, writer, log=t_train == 0)
#     974                             epoch_critic_losses.append(critic_loss)
#     975                             epoch_actor_losses.append(actor_loss)
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/ddpg/ddpg.py in _train_step(self, step, writer, log)
#     706
#     707         self.actor_optimizer.update(actor_grads, learning_rate=self.actor_lr)
# --> 708         self.critic_optimizer.update(critic_grads, learning_rate=self.critic_lr)
#     709
#     710         return critic_loss, actor_loss
#
# ~/anaconda3/lib/python3.7/site-packages/stable_baselines/common/mpi_adam.py in update(self, local_grad, learning_rate)
#      59         self.exp_avg = self.beta1 * self.exp_avg + (1 - self.beta1) * global_grad
#      60         self.exp_avg_sq = self.beta2 * self.exp_avg_sq + (1 - self.beta2) * (global_grad * global_grad)
# ---> 61         step = (- step_size) * self.exp_avg / (np.sqrt(self.exp_avg_sq) + self.epsilon)
#      62         self.setfromflat(self.getflat() + step)
#      63
#
# KeyboardInterrupt:
